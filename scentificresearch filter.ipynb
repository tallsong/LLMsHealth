# %%
import pandas as pd
import bibtexparser # Used to read .bib files
import re
pd.set_option("display.max_columns", None)

# %%
ieee_df = pd.read_csv("dataset/IEEE.csv")
ieee_df
# Out:
#                                         Document Title  \
# 0    Possibilities and Pitfalls of Generative Pre-T...
# 1    Enhancing Smart Healthcare Services Through De...
# 2    Chapter 9 Machine learning models for cost-eff...
# 3    Extracting Health Evidence Information from Bi...
# 4    Examining Trustworthiness of LLM-as-a-Judge Sy...
# ..                                                 ...
# 978  Predicting Tumor Type and Residual Status of S...
# 979  Improving Interpretability of Radiology Report...
# 980  An Extensive Diagnosis System of Early Depress...
# 981  RespBERT: A Multi-Site Validation of a Natural...
# 982  Generative AI for Virtual Staining in Histopat...
#
#                                                Authors  \
# 0                   T. Kumar; R. Kait; Ankita; S. Rani
# 1    S. J. Ahmed; S. B. Atham; H. Kadhim; D. Gupta;...
# 2                                  P. Singh; S. Tiwari
# 3                     M. A. Shahid; M. Afzal; H. Seker
# 4    C. Curran; N. Neehal; K. Murugesan; K. P. Bennett
# ..                                                 ...
# 978  P. C. Nair; D. Gupta; B. I. Devi; V. Kanjirang...
# 979  C. Zhao; K. Kudus; S. Ketabi; K. Namdar; M. W....
# 980  K. M. Anandkumar; S. Ajith; J. Bharathkumar; V...
# 981  A. Pathak; C. Marshall; C. Davis; P. Yang; R. ...
# 982  S. Illarionova; M. Sharaev; F. Gubanov; R. Ham...
#
#                                    Author Affiliations  \
# 0    CSE Department, JMIETI, Radaur, Yamunanagar, H...
# 1    Department of CSE, Madanapalle Institute of Te...
# 2                                               NA; NA
# 3    School of Computing and Digital Technology, Bi...
# 4    Department of Mathematical Sciences, Rensselae...
# ..                                                 ...
# 978  Department of Computer Science and Engineering...
# 979  Department of Mechanical and Industrial Engine...
# 980  Department of Computer Science and Engineering...
# 981  School of Interactive Computing, Georgia Insti...
# 982  BIMAI-Lab, Biomedically Informed Artificial In...
#
#                                      Publication Title Date Added To Xplore  \
# 0    2023 International Conference on Advanced Comp...          27 Feb 2024
# 1    2025 3rd International Conference on Intellige...          22 Apr 2025
# 2    Digital Transformation in Healthcare 5.0: Volu...                  NaN
# 3    2024 IEEE/ACM International Conference on Big ...           8 Apr 2025
# 4    2024 IEEE International Conference on Big Data...          16 Jan 2025
# ..                                                 ...                  ...
# 978                                        IEEE Access          30 Sep 2024
# 979  2024 IEEE EMBS International Conference on Bio...          17 Mar 2025
# 980  2023 3rd International Conference on Innovativ...          18 Apr 2024
# 981  IEEE Journal of Biomedical and Health Informatics          10 Feb 2025
# 982  2025 Fourteenth International Conference on Im...          10 Nov 2025
#
#      Publication Year Volume  Issue Start Page End Page  \
# 0                2023    NaN    NaN         37       44
# 1                2025    NaN    NaN        666      671
# 2                2024    NaN    NaN        245      276
# 3                2024    NaN    NaN        159      164
# 4                2024    NaN    NaN       4627     4631
# ..                ...    ...    ...        ...      ...
# 978              2024     12    NaN     134379   134410
# 979              2024    NaN    NaN          1        8
# 980              2023    NaN    NaN        796      803
# 981              2025     29    2.0       1455     1463
# 982              2025    NaN    NaN          1        1
#
#                                               Abstract       ISSN  \
# 0    For its potential use in healthcare, Generativ...        NaN
# 1    In order to enhance patient care and medical d...        NaN
# 2    Machine learning models have emerged as powerf...        NaN
# 3    The current biomedical literature is huge, uns...        NaN
# 4    Manual evaluation of Large Language Model (LLM...  2573-2978
# ..                                                 ...        ...
# 978  A suprasellar lesion is an unusual mass in the...  2169-3536
# 979  Radiology reports are crucial for bridging the...  2641-3604
# 980  Suicidal deaths caused by depression have been...        NaN
# 981  Acute respiratory distress syndrome (ARDS) is ...  2168-2208
# 982  Generative AI currently assists in solving var...  2154-512X
#
#                  ISBNs                                 DOI  \
# 0    979-8-3503-8088-0   10.1109/ICACCTech61146.2023.00016
# 1    979-8-3315-2389-3    10.1109/ISACC65211.2025.10969285
# 2        9783111327860                                 NaN
# 3    979-8-3503-6730-0       10.1109/BDCAT63179.2024.00035
# 4    979-8-3503-6248-0  10.1109/BigData62323.2024.10825592
# ..                 ...                                 ...
# 978                NaN         10.1109/ACCESS.2024.3460976
# 979  979-8-3503-5155-2      10.1109/BHI62660.2024.10913641
# 980  979-8-3503-4363-2   10.1109/ICIMIA60377.2023.10426578
# 981                NaN           10.1109/JBHI.2024.3502575
# 982  978-1-6654-5739-2     10.1109/IPTA66025.2025.11222016
#
#                                    Funding Information  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 978                                                NaN
# 979                                                NaN
# 980                                                NaN
# 981  Surgical Critical Care Initiative through the ...
# 982                                                NaN
#
#                                               PDF Link  \
# 0    https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 1    https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 2    https://ieeexplore.ieee.org/xpl/ebooks/bookPdf...
# 3    https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 4    https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# ..                                                 ...
# 978  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 979  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 980  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 981  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
# 982  https://ieeexplore.ieee.org/stamp/stamp.jsp?ar...
#
#                                        Author Keywords  \
# 0    Generative Pre-trained Transformers (GPT);Medi...
# 1    Smart Healthcare;Deep Learning;BioBERT;NER;Med...
# 2                                                  NaN
# 3    LLM;GPT 4;biomedical literature;health evidenc...
# 4                                                  NaN
# ..                                                 ...
# 978  Brain tumor;suprasellar lesions;discharge summ...
# 979  BERT;deep learning;keyword extraction;inter-pr...
# 980  Depression Detection;Suicide Prevention;Bidire...
# 981  Natural language processing;large language mod...
# 982                                                NaN
#
#                                             IEEE Terms  \
# 0    Ethics;Adaptation models;Education;Decision ma...
# 1    Deep learning;Data analysis;Accuracy;Decision ...
# 2                                                  NaN
# 3    Training;Costs;Accuracy;Systematics;Generative...
# 4    Measurement;Large language models;Semantics;Pr...
# ..                                                 ...
# 978  Lesions;Transformers;Encoding;Biological syste...
# 979  Pathology;Annotations;Large language models;Br...
# 980  Surveys;Mental health;Organizations;Depression...
# 981  Acute respiratory distress syndrome;Medical di...
# 982                                                NaN
#
#                                             Mesh_Terms  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 978                                                NaN
# 979                                                NaN
# 980                                                NaN
# 981  Humans;Respiratory Distress Syndrome;Natural L...
# 982                                                NaN
#
#      Article Citation Count  Patent Citation Count  Reference Count   License  \
# 0                       4.0                    NaN             26.0      IEEE
# 1                       1.0                    NaN             19.0      IEEE
# 2                       NaN                    NaN              NaN       NaN
# 3                       NaN                    NaN             22.0      IEEE
# 4                       1.0                    NaN             17.0      IEEE
# ..                      ...                    ...              ...       ...
# 978                     7.0                    NaN            102.0  CCBYNCND
# 979                     NaN                    NaN             30.0      IEEE
# 980                     NaN                    NaN             21.0      IEEE
# 981                     3.0                    NaN             26.0      IEEE
# 982                     NaN                    NaN              0.0      IEEE
#
#      Online Date  Issue Date  Meeting Date   Publisher  \
# 0    27 Feb 2024         NaN           NaN        IEEE
# 1    22 Apr 2025         NaN           NaN        IEEE
# 2    16 Sep 2025         NaN           NaN  De Gruyter
# 3     8 Apr 2025         NaN           NaN        IEEE
# 4    16 Jan 2025         NaN           NaN        IEEE
# ..           ...         ...           ...         ...
# 978  16 Sep 2024         NaN           NaN        IEEE
# 979  17 Mar 2025         NaN           NaN        IEEE
# 980  18 Apr 2024         NaN           NaN        IEEE
# 981  19 Nov 2024         NaN           NaN        IEEE
# 982  10 Nov 2025         NaN           NaN        IEEE
#
#            Document Identifier
# 0             IEEE Conferences
# 1             IEEE Conferences
# 2    De Gruyter eBook Chapters
# 3             IEEE Conferences
# 4             IEEE Conferences
# ..                         ...
# 978              IEEE Journals
# 979           IEEE Conferences
# 980           IEEE Conferences
# 981              IEEE Journals
# 982           IEEE Conferences
#
# [983 rows x 28 columns]

# %%
with open("dataset/acm.bib", encoding="utf-8") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# Convert entries to a pandas DataFrame
acm_df = pd.DataFrame(bib_database.entries)
acm_df
# Out:
#                                               keywords numpages      month  \
# 0    Computerized tomography, Large language models...       16  September
# 1    healthcare, large language models, multidiscip...       22        May
# 2    Clinical Analytics, FHIR, Health Informatics, ...        7        NaN
# 3    Reflective Learning, Community Health Nursing ...       10        NaN
# 4    whole genome sequencing, generative AI, large ...      NaN     August
# ..                                                 ...      ...        ...
# 843  COVID vaccines, Sentiment analysis, Artificial...       31        May
# 844                                                NaN       14        NaN
# 845  Passive sensing, clinical insights, large-lang...       25        May
# 846  Fake news detection, Knowledge graph, Multi-do...       28        May
# 847  Paperless environment, Optical Character Recog...       14    January
#
#                                                journal  \
# 0                            Eng. Appl. Artif. Intell.
# 1                     Proc. ACM Hum.-Comput. Interact.
# 2                                                  NaN
# 3                                                  NaN
# 4                   ACM Trans. Interact. Intell. Syst.
# ..                                                 ...
# 843                                    J. Supercomput.
# 844                                                NaN
# 845  Proc. ACM Interact. Mob. Wearable Ubiquitous T...
# 846                                    J. Supercomput.
# 847                             J. Intell. Fuzzy Syst.
#
#                                 doi  \
# 0    10.1016/j.engappai.2025.111094
# 1                   10.1145/3711055
# 2           10.1145/3698587.3701392
# 3      10.1007/978-3-031-98197-5_25
# 4                   10.1145/3756326
# ..                              ...
# 843      10.1007/s11227-023-05319-8
# 844                             NaN
# 845                 10.1145/3659604
# 846      10.1007/s11227-023-05381-2
# 847             10.3233/JIFS-221486
#
#                                                 url       issn number volume  \
# 0    https://doi.org/10.1016/j.engappai.2025.111094  0952-1976     PA    156
# 1                   https://doi.org/10.1145/3711055        NaN      2      9
# 2           https://doi.org/10.1145/3698587.3701392        NaN    NaN    NaN
# 3      https://doi.org/10.1007/978-3-031-98197-5_25        NaN    NaN    NaN
# 4                   https://doi.org/10.1145/3756326  2160-6455    NaN    NaN
# ..                                              ...        ...    ...    ...
# 843      https://doi.org/10.1007/s11227-023-05319-8  0920-8542     15     79
# 844                                             NaN        NaN    NaN    NaN
# 845                 https://doi.org/10.1145/3659604        NaN      2      8
# 846      https://doi.org/10.1007/s11227-023-05381-2  0920-8542     16     79
# 847             https://doi.org/10.3233/JIFS-221486  1064-1246      3     44
#
#                 address                            publisher issue_date  year  \
# 0                   USA                 Pergamon Press, Inc.   Sep 2025  2025
# 1     New York, NY, USA  Association for Computing Machinery   May 2025  2025
# 2     New York, NY, USA  Association for Computing Machinery        NaN  2024
# 3    Berlin, Heidelberg                      Springer-Verlag        NaN  2025
# 4     New York, NY, USA  Association for Computing Machinery        NaN  2025
# ..                  ...                                  ...        ...   ...
# 843                 USA           Kluwer Academic Publishers   Oct 2023  2023
# 844   Red Hook, NY, USA               Curran Associates Inc.        NaN  2023
# 845   New York, NY, USA  Association for Computing Machinery  June 2024  2024
# 846                 USA           Kluwer Academic Publishers   Nov 2023  2023
# 847                 NLD                            IOS Press       2023  2023
#
#                                                  title  \
# 0    Enhancing the effectiveness of emergency depar...
# 1    Reimagining Multidisciplinary Teams: Challenge...
# 2    FHIRViz: Multi-Agent Platform for FHIR Visuali...
# 3    Supporting Reflective Practice in Community He...
# 4    AI-Enhanced Sensemaking: Exploring the Design ...
# ..                                                 ...
# 843  Vaccine sentiment analysis using BERT&nbsp;+&n...
# 844  Interactive multi-fidelity learning for cost-e...
# 845  From Classification to Clinical Insights: Towa...
# 846  KG-MFEND: an efficient knowledge graph-based m...
# 847  An offline English optical character recogniti...
#
#                                                 author      ENTRYTYPE  \
# 0    Lin, Heng-Yu and Chang, Yung-Chun and Yang, Pe...        article
# 1    F Paulo, Soraia and Neto, Isabel and Figueired...        article
# 2    ALMutairi, Mariam and AlKulaib, Lulwah and Wan...  inproceedings
# 3    Huang, Yen-Yu and Lin, Chia-Ju and Chen, Ching...  inproceedings
# 4    Mastrianni, Angela and Twede, Hope and Sarcevi...        article
# ..                                                 ...            ...
# 843  Umair, Areeba and Masciari, Elio and Ullah, Mu...        article
# 844  Zhang, Jiaxin and Li, Zhuohang and Das, Kamali...  inproceedings
# 845  Englhardt, Zachary and Ma, Chengqian and Morri...        article
# 846        fu, Lifang and Peng, Huanxin and Liu, Shuai        article
# 847                  Suganthi, M. and Arun Prakash, R.        article
#
#                                  ID articleno  \
# 0    10.1016/j.engappai.2025.111094       NaN
# 1                   10.1145/3711055   CSCW157
# 2           10.1145/3698587.3701392        38
# 3      10.1007/978-3-031-98197-5_25       NaN
# 4                   10.1145/3756326       NaN
# ..                              ...       ...
# 843      10.1007/s11227-023-05319-8       NaN
# 844         10.5555/3666122.3669543      3421
# 845                 10.1145/3659604        56
# 846      10.1007/s11227-023-05381-2       NaN
# 847             10.3233/JIFS-221486       NaN
#
#                                               abstract    series  \
# 0                                                  NaN       NaN
# 1    Multidisciplinary teams are crucial in tailori...       NaN
# 2    The shift to electronic health records (EHRs) ...   BCB '24
# 3    In response to the increasing emphasis on refl...       NaN
# 4    Generative AI has the potential to transform k...       NaN
# ..                                                 ...       ...
# 843  Since the spread of the coronavirus flu in 201...       NaN
# 844  Large language models (LLMs) have demonstrated...  NIPS '23
# 845  Passively collected behavioral health data fro...       NaN
# 846  The widespread dissemination of fake news on s...       NaN
# 847  Everything becomes smart in the modern era, fo...       NaN
#
#                  location                                          booktitle  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2         Shenzhen, China  Proceedings of the 15th ACM International Conf...
# 3            Oslo, Norway  Innovative Technologies and Learning: 8th Inte...
# 4                     NaN                                                NaN
# ..                    ...                                                ...
# 843                   NaN                                                NaN
# 844  New Orleans, LA, USA  Proceedings of the 37th International Conferen...
# 845                   NaN                                                NaN
# 846                   NaN                                                NaN
# 847                   NaN                                                NaN
#
#                   isbn        pages           note
# 0                  NaN          NaN            NaN
# 1                  NaN          NaN            NaN
# 2        9798400713026          NaN            NaN
# 3    978-3-031-98196-8      225–234            NaN
# 4                  NaN          NaN  Just Accepted
# ..                 ...          ...            ...
# 843                NaN  17355–17385            NaN
# 844                NaN          NaN            NaN
# 845                NaN          NaN            NaN
# 846                NaN  18417–18444            NaN
# 847                NaN    3877–3890            NaN
#
# [848 rows x 25 columns]

# %%
springer_df = pd.read_parquet("dataset/springer.parquet")
springer_df
# Out:
#                                             Item Title  \
# 0    A study of generative large language model for...
# 1    Generative AI costs in large healthcare system...
# 2    Generative AI, IoT, and blockchain in healthca...
# 3    Assessing knowledge about medical physics in l...
# 4            The Impact of Generative AI on Healthcare
# ..                                                 ...
# 995  Evaluating the quality and readability of Chat...
# 996  A Retrieval-Augmented Framework Based on&#xa0;...
# 997  Leveraging Generative AI for Data Augmentation...
# 998  Synthetic medical education in dermatology lev...
# 999  Addressing fairness issues in deep learning-ba...
#
#                                      Publication Title  Book Series Title  \
# 0                                 npj Digital Medicine                NaN
# 1                                 npj Digital Medicine                NaN
# 2                          Discover Internet of Things                NaN
# 3                  Radiological Physics and Technology                NaN
# 4    Generative Artificial Intelligence (AI) Approa...                NaN
# ..                                                 ...                ...
# 995         European Archives of Oto-Rhino-Laryngology                NaN
# 996               Cyberspace Simulation and Evaluation                NaN
# 997               Generative AI in Creative Industries                NaN
# 998                               npj Digital Medicine                NaN
# 999                               npj Digital Medicine                NaN
#
#      Journal Volume  Journal Issue                      Item DOI  \
# 0               NaN            NaN    10.1038/s41746-023-00958-w
# 1               NaN            NaN    10.1038/s41746-025-01971-x
# 2               NaN            NaN    10.1007/s43926-025-00095-8
# 3               NaN            NaN    10.1007/s12194-024-00838-2
# 4               NaN            NaN   10.1007/978-3-031-76710-4_9
# ..              ...            ...                           ...
# 995             NaN            NaN    10.1007/s00405-024-09180-0
# 996             NaN            NaN   10.1007/978-981-96-4509-1_5
# 997             NaN            NaN  10.1007/978-3-031-89175-5_42
# 998             NaN            NaN    10.1038/s41746-025-01650-x
# 999             NaN            NaN    10.1038/s41746-024-01276-5
#
#                                                Authors  Publication Year  \
# 0    Cheng PengXi YangAokun ChenKaleb E. SmithNima ...              2023
# 1    Michael L. BurnsSsu-Ying ChenChu-An TsaiJohn V...              2025
# 2    Tehseen MazharSunawar khanTariq ShahzadMuhamma...              2025
# 3    Noriyuki KadoyaKazuhiro AraiShohei TanakaYuto ...              2024
# 4         Atianashie A. MiracleChukwuma Chinaza Adaobi              2025
# ..                                                 ...               ...
# 995  Alexander Z. FazilatCamille BrenacDanae Kawamo...              2024
# 996  Genggeng ZhangLinfeng LiHong ChenZhijie QiuLei...              2025
# 997                       Aysar SalloumSaid A. Salloum              2025
# 998  Arya S. RaoJohn KimAndrew MuCameron C. YoungEz...              2025
# 999  Zikang XuJun LiQingsong YaoHan LiMingyue ZhaoS...              2024
#
#                                                    URL      Content Type  \
# 0    https://link.springer.com/article/10.1038/s417...           Article
# 1    https://link.springer.com/article/10.1038/s417...           Article
# 2    https://link.springer.com/article/10.1007/s439...           Article
# 3    https://link.springer.com/article/10.1007/s121...           Article
# 4    https://link.springer.com/chapter/10.1007/978-...           Chapter
# ..                                                 ...               ...
# 995  https://link.springer.com/article/10.1007/s004...           Article
# 996  https://link.springer.com/chapter/10.1007/978-...  Conference paper
# 997  https://link.springer.com/chapter/10.1007/978-...           Chapter
# 998  https://link.springer.com/article/10.1038/s417...           Article
# 999  https://link.springer.com/article/10.1038/s417...           Article
#
#                                               Abstract
# 0    There are enormous enthusiasm and concerns in ...
# 1    Application of large language models in health...
# 2    This research contributes to the healthcare bu...
# 3    This study aimed to evaluate the performance f...
# 4    The advent of generative artificial intelligen...
# ..                                                 ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 11 columns]

# %%
# read pubmed parquet
pubmed_df = pd.read_parquet("dataset/pubmed.parquet")

pubmed_df
# Out:
#           PMID                                              Title  \
# 0     40936179  From Evidence to Recommendations With Large La...
# 1     38539117  Methodological insights into ChatGPT's screeni...
# 2     39103144  Navigating the frontier of drug-like chemical ...
# 3     38419083  Recommendations for diabetic macular edema man...
# 4     40699917  Perceptions and Attitudes of Chinese Oncologis...
# ...        ...                                                ...
# 3537  39499856  Enabling Demonstrated Consent for Biobanking w...
# 3538  38925234  The Large Language Model ChatGPT-4 Exhibits Ex...
# 3539  38337594  Artificial Intelligence Language Model Perform...
# 3540  41202205  A Prompt Engineering Framework for Large Langu...
# 3541  38189967  Reliability of large language models in managi...
#
#                                                 Authors  \
# 0     Zhao W, Xia D, Ye Z, Lai H, Sun M, Huang J, Li...
# 1     Issaiy M, Ghanaati H, Kolahi S, Shakiba M, Jal...
# 2                                          Lavecchia A.
# 3     Choudhary A, Gopalakrishnan N, Joshi A, Balakr...
# 4                   Zeng L, Li Q, Zuo Y, Zhang Y, Li Z.
# ...                                                 ...
# 3537  Barnes C, Aboy MR, Minssen T, Allen JW, Earp B...
# 3538  Kunze KN, Varady NH, Mazzucco M, Lu AZ, Chahla...
# 3539  Atkinson CJ, Seth I, Xie Y, Ross RJ, Hunter-Sm...
# 3540                                   Boit S, Patil R.
# 3541  Saibene AM, Allevi F, Calvo-Henriquez C, Mania...
#
#                                                Citation First Author  \
# 0     J Evid Based Med. 2025 Sep;18(3):e70067. doi: ...       Zhao W
# 1     BMC Med Res Methodol. 2024 Mar 27;24(1):78. do...     Issaiy M
# 2     Drug Discov Today. 2024 Sep;29(9):104133. doi:...  Lavecchia A
# 3     Int J Retina Vitreous. 2024 Feb 28;10(1):22. d...  Choudhary A
# 4     J Med Internet Res. 2025 Jul 23;27:e71418. doi...       Zeng L
# ...                                                 ...          ...
# 3537  Am J Bioeth. 2025 Apr;25(4):96-111. doi: 10.10...     Barnes C
# 3538  Arthroscopy. 2025 May;41(5):1438-1447.e14. doi...     Kunze KN
# 3539  J Clin Med. 2024 Feb 4;13(3):900. doi: 10.3390...  Atkinson CJ
# 3540  JMIR Ment Health. 2025 Nov 7;12:e75078. doi: 1...       Boit S
# 3541  Eur Arch Otorhinolaryngol. 2024 Apr;281(4):183...   Saibene AM
#
#                    Journal/Book  Publication Year Create Date        PMCID  \
# 0              J Evid Based Med              2025  2025/09/12         None
# 1          BMC Med Res Methodol              2024  2024/03/28  PMC10976661
# 2             Drug Discov Today              2024  2024/08/05         None
# 3         Int J Retina Vitreous              2024  2024/02/28  PMC10900631
# 4            J Med Internet Res              2025  2025/07/23  PMC12309621
# ...                         ...               ...         ...          ...
# 3537                Am J Bioeth              2025  2024/11/05  PMC12005476
# 3538                Arthroscopy              2025  2024/06/26         None
# 3539                 J Clin Med              2024  2024/02/10  PMC10856538
# 3540           JMIR Ment Health              2025  2025/11/07  PMC12594504
# 3541  Eur Arch Otorhinolaryngol              2024  2024/01/08  PMC10943141
#
#      NIHMS ID                            DOI  \
# 0        None             10.1111/jebm.70067
# 1        None     10.1186/s12874-024-02203-8
# 2        None   10.1016/j.drudis.2024.104133
# 3        None     10.1186/s40942-024-00544-6
# 4        None                  10.2196/71418
# ...       ...                            ...
# 3537     None  10.1080/15265161.2024.2416117
# 3538     None   10.1016/j.arthro.2024.06.021
# 3539     None            10.3390/jcm13030900
# 3540     None                  10.2196/75078
# 3541     None     10.1007/s00405-023-08372-4
#
#                                                Abstract
# 0     BACKGROUND: Formulating evidene-based recommen...
# 1     BACKGROUND: The screening process for systemat...
# 2     Deep generative models (GMs) have transformed ...
# 3     PURPOSE: To study the role of artificial intel...
# 4     BACKGROUND: Chatbots driven by large language ...
# ...                                                 ...
# 3537  Participation in research is supposed to be vo...
# 3538  PURPOSE: To provide a proof-of-concept analysi...
# 3539  Background: The integration of artificial inte...
# 3540  BACKGROUND: Artificial intelligence (AI), part...
# 3541  PURPOSE: This study aimed to evaluate the util...
#
# [3542 rows x 12 columns]

# %%
sciencedirect_df = pd.read_parquet("dataset/sciencedirect.parquet")
elsevier_df = sciencedirect_df

# %%
# 1. Create a list of tuples: (dataframe_name, title_series)
df_sources = [
    ("ACM", acm_df["title"]),
    ("Elsevier", elsevier_df["title"]),
    ("IEEE", ieee_df["Document Title"]),
    ("PubMed", pubmed_df["Title"]),
    ("Springer", springer_df["Item Title"])
]

# 2. Create a combined DataFrame with source information
combined_data = []
for source_name, title_series in df_sources:
    # Create a temporary DataFrame with title and source
    temp_df = pd.DataFrame({
        'title': title_series.str.lower(),  # Normalize to lowercase
        'source': source_name
    })
    combined_data.append(temp_df)

# Combine all into one DataFrame
all_titles_df = pd.concat(combined_data, ignore_index=True)
print(f"Amount of papers direct (from all libraries) directly after downloading / boolean queries:: {len(all_titles_df)}")

# 3. Remove rows with missing titles
all_titles_df = all_titles_df.dropna(subset=['title'])

# 4. Find titles that appear more than once
title_counts = all_titles_df['title'].value_counts()
duplicate_titles = title_counts[title_counts > 1].index.tolist()

# 5. Filter to show only duplicates and group by title
if not duplicate_titles:
    print("No duplicate titles found across the DataFrames.")
else:
    duplicates_df = all_titles_df[all_titles_df['title'].isin(duplicate_titles)]
    
    print(f"Found {len(duplicate_titles)} duplicate titles across datasets")
    print(f"Total duplicate entries: {len(duplicates_df)}")
    print("=" * 80)
    # Group by title and show which sources contain each duplicate
    for title in sorted(duplicate_titles):
        title_data = duplicates_df[duplicates_df['title'] == title]
        sources = title_data['source'].tolist()
        count = len(sources)

        
        print(f"\nTitle: {title}")
        print(f"   Total occurrences: {count}")
        print(f"   Found in: {', '.join(sources)}")
# Out:
# Amount of papers direct (from all libraries) directly after downloading / boolean queries:: 7073
# Found 529 duplicate titles across datasets
# Total duplicate entries: 1090
# ================================================================================
#
# Title: [impacts and implications of conversational artificial intelligence tools in hematology: a critical evaluation of performance and patient perception]
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a 360° view for large language models: early detection of amblyopia in children using multi-view eye movement recordings
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: a case study on using a large language model to analyze continuous glucose monitoring data
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a chatbot based question and answer system for the auxiliary diagnosis of chronic diseases based on large language model
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a collaborative large language model for drug analysis
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a comparative study of recent large language models on generating hospital discharge summaries for lung cancer patients
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: a comparative study of responses to retina questions from either experts, expert-edited large language models, or expert-edited large language models alone
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a comprehensive evaluation of large language models for information extraction from unstructured electronic health records in residential aged care
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a comprehensive survey of large language models and multimodal large language models in medicine
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: a controlled trial examining large language model conformity in psychiatric assessment using the asch paradigm
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a framework for considering the use of generative ai for health
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a generative ai teaching assistant for personalized learning in medical education
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a generative ai-discovered tnik inhibitor for idiopathic pulmonary fibrosis: a randomized phase 2a trial
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a large language model digital patient system enhances ophthalmology history taking skills
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: a large language model in solving primary healthcare issues: a potential implication for remote healthcare and medical education
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a large language model to detect negated expressions in radiology reports
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a large language model-based clinical decision support system for syncope recognition in the emergency department: a framework for clinical workflow integration
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: a large language model-based generative natural language processing framework fine-tuned on clinical notes accurately extracts headache frequency from electronic health records
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a longitudinal analysis of declining medical safety messaging in generative ai models
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: a medical multimodal large language model for future pandemics
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a multimodal generative ai copilot for human pathology
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a multimodal large language model as an end-to-end classifier of thyroid nodule malignancy risk: usability study
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: a novel approach for perceptions of physician decision-making and latent topic refinement in large language model-enhanced medical dialog generation
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: a novel cognitive behavioral therapy-based generative ai tool (socrates 2.0) to facilitate socratic dialogue: protocol for a mixed methods feasibility study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a novel large language model enhanced joint learning framework for fine-grained sentiment analysis on drug reviews
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: a pathway from fragmentation to interoperability through standards-based enterprise architecture to enhance patient safety
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a promising start and not a panacea: chatgpt's early impact and potential in medical science and biomedical engineering research
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a rapid review on current and potential uses of large language models in nursing
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: a real-time approach for surgical activity recognition and prediction based on transformer models in robot-assisted surgery
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a review on generative ai models for synthetic medical text, time series, and longitudinal data
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a scoping review of large language model based approaches for information extraction from radiology reports
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a scoping review on generative ai and large language models in mitigating medication related harm
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a six-tiered framework for evaluating ai models from repeatability to replaceability
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a strategy for cost-effective large language model use at health system-scale
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a study of generative large language model for medical research and healthcare
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a systematic review and meta-analysis of diagnostic performance comparison between generative ai and physicians
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a systematic review of generative ai approaches for medical image enhancement: comparing gans, transformers, and diffusion models
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: a systematic review of large language model (llm) evaluations in clinical medicine
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: a task-unified network with transformer and spatial-temporal convolution for left ventricular quantification
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: accelerating histopathology workflows with generative ai-based virtually multiplexed tumour profiling
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: accuracy and consistency of online large language model-based artificial intelligence chat platforms in answering patients' questions about heart failure
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: accuracy of generative artificial intelligence models in differential diagnoses of familial mediterranean fever and deficiency of interleukin-1 receptor antagonist
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: accuracy of llms in medical education: evidence from a concordance test with medical teacher
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: adaptive robot-mediated assessment using llm for enhanced survey quality in older adults care programs
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: addressing 6 challenges in generative ai for digital health: a scoping review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: adopting and expanding ethical principles for generative artificial intelligence from military to healthcare
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: adoption of large language model ai tools in everyday tasks: multisite cross-sectional qualitative study of chinese hospital administrators
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: advancing chinese biomedical text mining with community challenges
#    Total occurrences: 3
#    Found in: ACM, PubMed, PubMed
#
# Title: advancing diabetic foot ulcer care: ai and generative ai approaches for classification, prediction, segmentation, and detection
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: advancing health coaching: a comparative study of large language model and health coaches
#    Total occurrences: 3
#    Found in: ACM, Elsevier, PubMed
#
# Title: advancing the frontier of artificial intelligence on emerging technologies to redefine cancer diagnosis and care
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: advancing the production of clinical medical devices through chatgpt
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: agent-guided ai-powered interpretation and reporting of nerve conduction studies and emg (inspire)
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: ai agents in clinical medicine: a systematic review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: ai misuse of retracted literature: a comparative study of chatgpt4o, deepseek, and grok 3 in stem cell research
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: ai-driven innovations for secure and efficient medical consultations
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: aligning, autoencoding and prompting large language models for novel disease reporting
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: an australasian survey on the use of chatgpt and other large language models in medical physics
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: an empirical evaluation of prompting strategies for large language models in zero-shot clinical natural language processing: algorithm development and validation study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: an exploratory survey about using chatgpt in education, healthcare, and research
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: an open-source fine-tuned large language model for radiological impression generation: a multi-reader performance study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: analyzing evaluation methods for large language models in the medical field: a scoping review
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: application of transformer neural networks for data cleaning in emergency room logs: a case study from the bordeaux university hospital
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: applications and future prospects of medical llms: a survey based on the m-kat conceptual framework
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: applying generative ai with retrieval augmented generation to summarize and extract key clinical information from electronic health records
#    Total occurrences: 3
#    Found in: ACM, PubMed, PubMed
#
# Title: are large language models qualified reviewers in originality evaluation?
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: are large language models valid tools for patient information on lumbar disc herniation? the spine surgeons' perspective
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: arthrosis diagnosis and treatment recommendations in clinical practice: an exploratory investigation with the generative ai model gpt-4
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: artificial intelligence (ai) for neurologists: do digital neurones dream of electric sheep?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: artificial intelligence in action: racial and gender disparities in academic radiology
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: artificial intelligence in radiology: performance of chatgpt-4v and gpt-4o on diagnostic radiology in-training (dxit) examination questions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: artificial intelligence meets dairy cow research: large language model's application in extracting daily time-activity budget data for a meta-analytical study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: artificial intelligence-assisted academic writing: recommendations for ethical use
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: artificial intelligence-assisted matching of human postmortem donors to ocular research projects
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: artificial intelligence-based applications for bone fracture detection using medical images: a systematic review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: artificial intelligence-based chatbots improve the efficiency of course orientation among medical students: a cross-sectional study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: artificial intelligence-enabled point-of-care echocardiography: bringing precision imaging to the bedside
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assertion detection in clinical natural language processing using large language models
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing and optimizing large language models on spondyloarthritis multi-choice question answering: protocol for enhancement and assessment
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing deepseek-r1 for clinical decision support in multidisciplinary laboratory medicine
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing knowledge about medical physics in language-generative ai with large language model: using the medical physicist exam
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: assessing large language model performance related to aging in genetic conditions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing racial and ethnic bias in text generation by large language models for health care–related tasks: cross-sectional study
#    Total occurrences: 2
#    Found in: Elsevier, Elsevier
#
# Title: assessing the ability of a large language model to score free-text medical student clinical notes: quantitative study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: assessing the current limitations of large language models in advancing health care education
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: assessing the feasibility and acceptability of a bespoke large language model pipeline to extract data from different study designs for public health evidence reviews
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing the performance of zero-shot visual question answering in multimodal large language models for 12-lead ecg image interpretation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing the quality of ai-generated clinical notes: validated evaluation of a large language model ambient scribe
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing the reliability of chatgpt in cytogenetic reporting and interpretation: implications for clinical use
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessing the utility of chatgpt throughout the entire clinical workflow: development and usability study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessment of a zero-shot large language model in measuring documented goals-of-care discussions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: assessment of large language model performance on medical school essay-style concept appraisal questions: exploratory study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: attention is not all you need: the complicated case of ethically using large language models in healthcare and medicine
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: auditing the inference processes of medical-image classifiers by leveraging generative ai and the expertise of physicians
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: automated esophageal cancer staging from free-text radiology reports: large language model evaluation study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: automated literature screening for hepatocellular carcinoma treatment through integration of 3 large language models: methodological study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: automated mass extraction of over 680,000 picos from clinical study abstracts using generative ai: a proof-of-concept study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: automated radiology report labeling in chest x-ray pathologies: development and evaluation of a large language model framework
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: automated sleep staging via parallel frequency-cut attention
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: automated structured data extraction from intraoperative echocardiography reports using large language models
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: automatic quantitative stroke severity assessment based on chinese clinical named entity recognition with domain-adaptive pre-trained large language model
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: bc4llm: a perspective of trusted artificial intelligence when blockchain meets large language models
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: benchmarking the confidence of large language models in answering clinical questions: cross-sectional evaluation study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: better understanding: can a large language model safely improve readability of patient information leaflets in interventional radiology?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: beyond the screen: the impact of generative artificial intelligence (ai) on patient learning and the patient-physician relationship
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: biomedical natural language processing in the era of large language models
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: biomedrag: a retrieval augmented large language model for biomedicine
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: breast-crag: a breast cancer large language model leveraging retrieval-augmented generation
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: bridging generational gaps in medication safety: insights from nurses, students, and generative ai models
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: bridging the gap in neonatal care: evaluating ai chatbots for chronic neonatal lung disease and home oxygen therapy management
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: camera-based monocular depth estimation in orthodontics: vision transformer vs. cnn model performance
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: can a large language model inform patients about auditory brainstem implants?
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: can chatgpt help patients answer their otolaryngology questions?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: can generative ai improve the readability of patient education materials at a radiology practice?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: can large language models address unmet patient information needs and reduce provider burnout in the management of thyroid disease?
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: cd-tron: leveraging large clinical language model for early detection of cognitive decline from electronic health records
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: cellular morphometric biomarkers and large language model predict prognosis and treatment response in neuroblastoma patients: a retrospective and double-blind prospective single arm clinical study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: challenges and applications in generative ai for clinical tabular data in physiology
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: characterizing research domain criteria symptoms among psychiatric inpatients using large language models
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: chat gpt as a neuro-score calculator: analysis of a large language model's performance on various neurological exam grading scales
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatbot for the return of positive genetic screening results for hereditary cancer syndromes: prompt engineering project
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt and medicine: together we embrace the ai renaissance
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt and the medical industry: a topic modeling of online discussions by medical professionals
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: chatgpt as a decision-support tool for better self-monitoring of hearing
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt as a tool for biostatisticians: a tutorial on applications, opportunities, and limitations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt for dermatology students: studying how input format affects reliability
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt in ultrasound medicine: potential applications and challenges
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: chatgpt performance deteriorated in patients with comorbidities when providing cardiological therapeutic consultations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt use among pediatric health care providers: cross-sectional survey study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatgpt vs. web search for patient questions: what does chatgpt do better?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chatting new territory: large language models for infection surveillance from pilot to deployment
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: chinese medical named entity recognition enhanced by large language model
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: classifying unstructured text in electronic health records for mental health prediction models: large language model evaluation study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: clinical application potential of large language model: a study based on thyroid nodules
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: clinical concept and relation extraction using prompt-based machine reading comprehension
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: clinical decision support for pharmacologic management of treatment-resistant depression with augmented large language models
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: clinical sentiment analysis by large language models enhances prediction of hepatorenal syndrome
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: clinician perspectives on ai-generated drafts of patient test result explanations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: coherence and comprehensibility: large language models predict lay understanding of health-related content
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: comparative analysis of accuracy and completeness in standardized database generation for complex multilingual lung cancer pathological reports: large language model-based assisted diagnosis system vs. deepseek, gpt-3.5, and healthcare professionals with varied professional titles, with task load variation assessment among medical staff
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: comparative analysis of large language models in chinese medical named entity recognition
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: comparative assessment of artificial intelligence chatbots' performance in responding to healthcare professionals' and caregivers' questions about dravet syndrome
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: comparative benchmarking of the deepseek large language model on medical tasks and clinical reasoning
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: comparative diagnostic performance of a multimodal large language model versus a dedicated electrocardiogram ai in detecting myocardial infarction from electrocardiogram images: comparative study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: comparing diagnostic accuracy of clinical professionals and large language models: systematic review and meta-analysis
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: comparison of artificial intelligence large language model chatbots in answering frequently asked questions in anaesthesia
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: comparison of ophthalmologist and large language model chatbot responses to online patient eye care questions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: comparison of physician and large language model chatbot responses to online ear, nose, and throat inquiries
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: comparison of the performance of gpt-3.5 and gpt-4 with that of medical students on the written german medical licensing examination: observational study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: comparison of the readability of chatgpt and bard in medical communication: a meta-analysis
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: competency of large language models in evaluating appropriate responses to suicidal ideation: comparative study
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: constructing a high-quality english and korean medical corpus for medical large language model
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: contextualized medication information extraction using transformer-based deep learning architectures
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: contraception-related topics in chat dialogues between healthcare students and generative ai patients: a natural language processing analysis
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: cost, usability, credibility, fairness, accountability, transparency, and explainability framework for safe and effective large language models in medical education: narrative review and qualitative study
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: creating, anonymizing and evaluating the first medical language model pre-trained on dutch electronic health records: medroberta.nl
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: criteria and protocol: assessing generative ai efficacy in perceiving eular 2019 lupus classification
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: culturally responsive communication in generative ai: looking at chatgpt’s advice for coming out
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: current landscape and future directions regarding generative large language models in stroke care: scoping review
#    Total occurrences: 3
#    Found in: Elsevier, Elsevier, PubMed
#
# Title: cxr-llava: a multimodal large language model for interpreting chest x-ray images
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: de novo generation of colorectal patient educational materials using large language models: prompt engineering key to improved readability
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: deep learning-based classification of lymphedema and other lower limb edema diseases using clinical images
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: demystifying the ethical framework for generative ai in healthcare: a data science perspective
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: dentists' refusal to manage patients with hiv, tuberculosis, hbv, hcv, epilepsy, and financial limitations in damascus, syria: a cross-sectional study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: designing a healthcare co-pilot with generative ai
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: detecting the clinical features of difficult-to-treat depression using synthetic data from large language models
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: developing a generative ai-powered chatbot for analyzing maude database
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: development and prospective implementation of a large language model based system for early sepsis prediction
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: development and validation of a large language model–powered chatbot for neurosurgery: mixed methods study on enhancing perioperative patient education
#    Total occurrences: 2
#    Found in: Elsevier, Elsevier
#
# Title: development of a large-scale medical visual question-answering dataset
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: development of a preliminary patient safety classification system for generative ai
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: diagnostic accuracy and clinical value of a domain-specific multimodal generative ai model for chest radiograph report generation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: diagnostic accuracy of a custom large language model on rare pediatric disease case reports
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: diri: adversarial patient reidentification with large language models for evaluating clinical text anonymization
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: disease progression strikingly differs in research and real-world parkinson's populations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: distilling the knowledge from large-language model for health event prediction
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: dmnag: prediction of disease-metabolite associations based on neighborhood aggregation graph transformer
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: dr. gai: significance of generative ai in plastic surgery
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: early alzheimer's detection through voice analysis: harnessing locally deployable llms via adetectolocum, a privacy-preserving diagnostic system
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: echoing intelligence: assessing the capabilities of a novel generative ai with a large language model in cardiology education
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: editorial commentary: shifting from redundancy to rigor in orthopaedic large language model research
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: editors' statement on the responsible use of generative ai technologies in scholarly journal publishing
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: eegconvnext: a novel convolutional neural network model for automated detection of alzheimer's disease and frontotemporal dementia using eeg signals
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: effectiveness of various general large language models in clinical consensus and case analysis in dental implantology: a comparative study
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: effects of generative artificial intelligence on cognitive effort and task performance: study protocol for a randomized controlled experiment among college students
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: ems-bert: a pre-trained language representation model for the emergency medical services (ems) domain
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: energy-efficient edge deployment of generative ai models using federated learning
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: enhancing automatic multilabel diagnosis of electrocardiogram signals: a masked transformer approach
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: enhancing awareness and self-diagnosis of obstructive sleep apnea using ai-powered chatbots: the role of chatgpt in revolutionizing healthcare
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: enhancing clinical data extraction from pathology reports: a comparative analysis of large language models
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing data quality in medical concept normalization through large language models
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: enhancing disease clustering through symptom-based analysis and large language model interpretations
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: enhancing healthcare worker mental health via artificial intelligence-driven work process improvements: a scoping review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing icd-9 code prediction with bert: a multi-label classification approach using mimic-iii clinical data
#    Total occurrences: 3
#    Found in: IEEE, IEEE, IEEE
#
# Title: enhancing kidney transplant care through the integration of chatbot
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing large language model reliability: minimizing hallucinations with dual retrieval-augmented generation based on the latest diabetes guidelines
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing multilingual patient education: chatgpt's accuracy and readability for ssnhl queries in english and spanish
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing oncological surveillance through large language model-assisted analysis: a comparative study of gpt-4 and gemini in evaluating oncological issues from serial abdominal ct scan reports
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: enhancing patient acceptance of robotic ultrasound through conversational virtual agent and immersive visualizations
#    Total occurrences: 3
#    Found in: ACM, IEEE, PubMed
#
# Title: enhancing post-traumatic stress disorder patient assessment: leveraging natural language processing for research of domain criteria identification using electronic medical records
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing professional communication training in higher education through artificial intelligence(ai)-integrated exercises: study protocol for a randomised controlled trial
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: enhancing puncture skills training with generative ai and digital technologies: a parallel cohort study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: enhancing radiomics features via a large language model for classifying benign and malignant breast tumors in mammography
#    Total occurrences: 3
#    Found in: ACM, Elsevier, PubMed
#
# Title: enhancing the accuracy of human phenotype ontology identification: comparative evaluation of multimodal large language models
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: enhancing visual reasoning with llm-powered knowledge graphs for visual question localized-answering in robotic surgery
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: environment scan of generative ai infrastructure for clinical and translational science
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: establishing responsible use of ai guidelines: a comprehensive case study for healthcare institutions
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: estimating the plausibility of commonsense statements by novelly fusing large language model and graph neural network
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: ethical and legal governance of generative ai in chinese healthcare
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating a customised large language model (delstar) and its ability to address medication-related questions associated with delirium: a quantitative exploratory study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating a large language model's ability to answer clinicians' requests for evidence summaries
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating a large language model's accuracy in chest x-ray interpretation for acute thoracic conditions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating ai-powered q&a systems: a simple approach to determining the need for expert ratings
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating and improving syndrome differentiation thinking ability in large language models: method development study
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: evaluating chatgpt's accuracy and readability in responding to common ophthalmology questions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating chatgpt's diagnostic accuracy in detecting fundus images
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating diagnostic accuracy and treatment efficacy in mental health: a comparative analysis of large language model tools and mental health professionals
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating evidence-based health information from generative ai using a cross-sectional study with laypeople seeking screening information
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating large language model (llm) performance on established breast classification systems
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating large language model performance to support the diagnosis and management of patients with primary immune disorders
#    Total occurrences: 4
#    Found in: Elsevier, Elsevier, PubMed, PubMed
#
# Title: evaluating large language model workflows in clinical decision support for triage and referral and diagnosis
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating large language model's accuracy in current procedural terminology coding given operative note templates across various plastic surgery sub-specialties
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating large language models in ophthalmology: systematic review
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: evaluating large language models on a highly-specialized topic, radiation oncology physics
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating large language models on medical, lay-language, and self-reported descriptions of genetic conditions
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating normative representation learning in generative ai for robust anomaly detection in brain imaging
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating the accuracy and relevance of chatgpt responses to frequently asked questions regarding total knee replacement
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating the capabilities of generative ai tools in understanding medical papers: qualitative study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating the effectiveness of large language models in addressing patient queries regarding maxillomandibular fixation for maxillofacial fractures
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: evaluating the feasibility of chatgpt in healthcare: an analysis of multiple clinical and research scenarios
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating the o1 reasoning large language model for cognitive bias: a vignette study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating the openai's gpt-3.5 turbo's performance in extracting information from scientific articles on diabetic retinopathy
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating the performance of deepseek-r1 and deepseek-v3 versus openai models in the chinese national medical licensing examination: cross-sectional comparative study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating the performance of gpt-3.5, gpt-4, and gpt-4o in the chinese national medical licensing examination
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: evaluating the strengths and limitations of multimodal chatgpt-4 in detecting glaucoma using fundus images
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluating the utility of a large language model in answering common patients' gastrointestinal health-related questions: are we there yet?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluation of a large language model to simplify discharge summaries and provide cardiological lifestyle recommendations
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: evaluation of chatgpt as a supplementary tool for pituitary adenomas: an observational study based on simulated consultations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluation of chatgpt as a tool for answering clinical questions in pharmacy practice
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluation of chatgpt-4 responses on physical activity guidance in children with cystic fibrosis: reliability, quality, and readability
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluation of chatgpt-generated medical responses: a systematic review and meta-analysis
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: evaluation of general-purpose large language models as diagnostic support tools in cervical cytology
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: evaluation of large language model performance on the multi-specialty recruitment assessment (msra) exam
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: evaluation of large language models' ability to identify clinically relevant drug-drug interactions and generate high-quality clinical pharmacotherapy recommendations
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: evaluation of pseudonymization of japanese progress notes by llm
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: examining the validity of chatgpt in identifying relevant nephrology literature: findings and implications
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: expert assessment of chatgpt's ability to generate illness scripts: an evaluative study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: explainable feature engineering in health data science: empirical comparison of chatgpt-4o and classical machine learning methods
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: exploring applications of artificial intelligence in critical care nursing: a systematic review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring chatgpt's potential in the clinical stream of neurorehabilitation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring inflammatory bowel disease discourse on reddit throughout the covid-19 pandemic using openai's gpt-3.5 turbo model: classification model validation and case study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring prompt-based large language model (llm) approach for medication error-related named entity recognition in medical incident reports
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring the credibility of large language models for mental health support: protocol for a scoping review
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: exploring the current applications and effectiveness of chatgpt in nursing: an integrative review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring the possibilities and limitations of customized large language model to support and improve cervical cancer screening
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: exploring the possible use of ai chatbots in public health education: feasibility study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: exploring the role of artificial intelligence, large language models: comparing patient-focused information and clinical decision support capabilities to the gynecologic oncology guidelines
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: extracting critical clinical indicators and survival prediction of lung cancer from pathology reports using large language models
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: extracting health evidence information from biomedical literature using large language models
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: extracting multifaceted characteristics of patients with chronic disease comorbidity: framework development using large language models
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: eye-llama, an in-domain large language model for ophthalmology
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: eyegpt for patient inquiries and medical education: development and validation of an ophthalmology large language model
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: feature decomposition via shared low-rank matrix recovery for ct report generation
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: federated transfer learning for chest x-ray classification: an explainable and generative ai framework with reliability assessment
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: fields of the future: digital transformation in smart agriculture with large language models and generative ai
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: fine-tuning large language models for improved health communication in low-resource languages
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: fine-tuning large language models for rare disease concept normalization
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: fine-tuning methods for large language models in clinical medicine by supervised fine-tuning and direct preference optimization: comparative evaluation
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: focus-transunet3d: high-precision model for 3d segmentation of medical point targets
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: foundation metrics for evaluating effectiveness of healthcare conversations powered by generative ai
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: from apomediation to aimediation: generative ai and the reconfiguration of informational authority in health communication
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: from chaos to symbiosis: exploring adaptive co-evolution strategies for generative ai and research integrity systems
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: from digital assistants to clinical partners: revolutionizing pediatric urology through large language model-powered decision support and patient education
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: from large language models to multimodal ai: a scoping review on the potential of generative ai in medicine
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: from patient consultations to graphs: leveraging llms for patient journey knowledge graph construction
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: gender representation of health care professionals in large language model-generated stories
#    Total occurrences: 2
# ...
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: quality of human expert vs large language model-generated multiple-choice questions in the field of mechanical ventilation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: racial, ethnic, and sex bias in large language model opioid recommendations for pain management
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: radiology report generation using automatic keyword adaptation, frequency-based multi-label classification and text-to-text large language models
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: rapidly benchmarking large language models for diagnosing comorbid patients: comparative study leveraging the llm-as-a-judge method
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: rdscan: extracting rna-disease relationship from the literature based on pre-training model
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: real-world type 2 diabetes second-line treatment allocation among patients
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: recommendations for clinicians, technologists, and healthcare organizations on the use of generative artificial intelligence in medicine: a position statement from the society of general internal medicine
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: recommendations for diabetic macular edema management by retina specialists and large language model-based artificial intelligence platforms
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: recommendations for initial diabetic retinopathy screening of diabetic patients using large language model-based artificial intelligence in real-life case scenarios
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: reliability and usefulness of chatgpt for inflammatory bowel diseases: an analysis for patients and healthcare professionals
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: remixformer++: a multi-modal transformer model for precision skin tumor differential diagnosis with memory-efficient attention
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: reporting guideline for chatbot health advice studies: the chart statement
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: research on a traditional chinese medicine case-based question-answering system integrating large language models and knowledge graphs
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: research trends on ai in breast cancer diagnosis, and treatment over two decades
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: reshaping free-text radiology notes into structured reports with generative question answering transformers
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: results and implications for generative ai in a large introductory biomedical and health informatics course
#    Total occurrences: 3
#    Found in: PubMed, PubMed, Springer
#
# Title: revealing patient dissatisfaction with health care resource allocation in multiple dimensions using large language models and the international classification of diseases 11th revision: aspect-based sentiment analysis
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: risk stratification of potential drug interactions involving common over-the-counter medications and herbal supplements by a large language model
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: seven failure points when engineering a retrieval augmented generation system
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: sex disparities in outcome of medication-assisted therapy of opioid use disorder: nationally representative study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: short-term and long-term causal effect estimation with double-head transformer
#    Total occurrences: 2
#    Found in: IEEE, IEEE
#
# Title: sigphi-med: a lightweight vision-language assistant for biomedicine
#    Total occurrences: 2
#    Found in: ACM, PubMed
#
# Title: simulation-based evaluation of large language models for comorbidity detection in sleep medicine - a pilot study on chatgpt o1 preview
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: spec: a soft prompt-based calibration on performance variability of large language model in clinical notes summarization
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: special issue european journal of physiology: artificial intelligence in the field of physiology and medicine
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: specialized large language model outperforms neurologists at complex diagnosis in blinded case-based evaluation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: spotlighting healthcare frontline workers´ perceptions on artificial intelligence across the globe
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: student perceptions of genai as a virtual tutor to support collaborative research training for health professionals
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: supervised natural language processing classification of violent death narratives: development and assessment of a compact large language model
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: taming large language models to implement diagnosis and evaluating the generation of llms at the semantic similarity level in acupuncture and moxibustion
#    Total occurrences: 2
#    Found in: ACM, Elsevier
#
# Title: task as context prompting for accurate medical symptom coding using large language models
#    Total occurrences: 2
#    Found in: ACM, IEEE
#
# Title: tcmchat: a generative large language model for traditional chinese medicine
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: team science in interdisciplinary health professions education research: a multi-institutional case study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: the accuracy and capability of artificial intelligence solutions in health care examinations and certificates: systematic review and meta-analysis
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the breakthrough of large language models release for medical applications: 1-year timeline and perspectives
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: the clinical application potential assessment of the deepseek-r1 large language model in lung cancer
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the double-edged sword of generative ai: surpassing an expert or a deceptive "false friend"?
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the emerging role of generative artificial intelligence in transplant medicine
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the ethics and governance of large language models in dentistry: a framework for research and clinical implementation
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the impact of ai-driven chatbot assistance on protocol development and clinical research engagement: an implementation report
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the impact of the large language model chatgpt in oral and maxillofacial surgery: a systematic review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the large language models on biomedical data analysis: a survey
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: the pdc30 chatbot-development of a psychoeducational resource on dementia caregiving among family caregivers: mixed methods acceptability study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the picasso's skepticism on computer science and the dawn of generative ai: questions after the answers to keep "machines-in-the-loop"
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the promise of ai large language models for epilepsy care
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the quality and safety of using generative ai to produce patient-centred discharge instructions
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: the relevance of general intelligence measurement in deep learning for healthcare
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the role of generative ai tools in case-based learning and teaching evaluation of medical biochemistry
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: the role of large language models in transforming emergency medicine: scoping review
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the tools of the future are the challenges of today: the use of chatgpt in problem-based learning medical education
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: the use of artificial intelligence (ai) in research: a review of author guidelines in leading journals across eight social science disciplines
#    Total occurrences: 2
#    Found in: ACM, Springer
#
# Title: the utility and implications of ambient scribes in primary care
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: toward digital twins in the intensive care unit: a medication management case study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: towards generative digital twins in biomedical research
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: traditional machine learning, deep learning, and bert (large language model) approaches for predicting hospitalizations from nurse triage notes: comparative evaluation of resource management
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: transformer models in healthcare: a survey and thematic analysis of potentials, shortcomings and risks
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: transforming military healthcare education and training: ai integration for future readiness
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: transforming the primary care journey with generative ai: a foundation model to boost efficiency, quality, and engagement
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: transmatch: a transformer-based multilevel dual-stream feature matching network for unsupervised deformable image registration
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: two-dimensional hybrid incremental learning (2dhil) framework for semantic segmentation of skin tissues
#    Total occurrences: 2
#    Found in: ACM, ACM
#
# Title: ultrasound report generation with fuzzy knowledge and multi-modal large language model
#    Total occurrences: 2
#    Found in: Elsevier, Elsevier
#
# Title: uncertainty-aware medical diagnostic phrase identification and grounding
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: understanding natural language: potential application of large language models to ophthalmology
#    Total occurrences: 3
#    Found in: Elsevier, PubMed, PubMed
#
# Title: unveiling gpt-4v's hidden challenges behind high accuracy on usmle questions: observational study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: unveiling the potential of large language models in transforming chronic disease management: mixed methods systematic review
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: urban safety perception assessments via integrating multimodal large language models with street view images
#    Total occurrences: 2
#    Found in: Elsevier, Elsevier
#
# Title: use of a large language model (llm) for ambulance dispatch and triage
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: use of large language model-based chatbots in managing the rehabilitation concerns and education needs of outpatient stroke survivors and caregivers
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: using a large language model (chatgpt) to assess risk of bias in randomized controlled trials of medical interventions: protocol for a pilot study of interrater agreement with human reviewers
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: using artificial intelligence to generate medical literature for urology patients: a comparison of three different large language models
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using artificial intelligence to provide a 'flipped assessment' approach to medical education learning opportunities
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: using chatgpt to improve the presentation of plain language summaries of cochrane systematic reviews about oncology interventions: cross-sectional study
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: using generative ai to extract structured information from free text pathology reports
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: using large language model (llm) to identify high-burden informal caregivers in long-term care
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to abstract complex social determinants of health from original and deidentified medical notes: development and validation study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to assess burnout among health care workers in the context of covid-19 vaccine decisions and health beliefs: retrospective cohort study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to assess the consistency of randomized controlled trials on ai interventions with consort-ai: cross-sectional survey
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to automate data extraction from surgical pathology reports: retrospective cohort study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to enhance exercise recommendations and physical activity in clinical and healthy populations: scoping review
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using large language models to generate educational materials on childhood glaucoma
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: using synthetic health care data to leverage large language models for named entity recognition: development and validation study
#    Total occurrences: 3
#    Found in: Elsevier, Elsevier, PubMed
#
# Title: utilization of generative ai-drafted responses for managing patient-provider communication
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: utilizing a domain-specific large language model for li-rads v2018 categorization of free-text mri reports: a feasibility study
#    Total occurrences: 2
#    Found in: PubMed, Springer
#
# Title: utilizing large language models in infectious disease transmission modelling for public health preparedness
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: viability of open large language models for clinical documentation in german health care: real-world model evaluation study
#    Total occurrences: 2
#    Found in: Elsevier, PubMed
#
# Title: voice-enabled response analysis agent (veraa): leveraging large language models to map voice responses in sdoh survey
#    Total occurrences: 2
#    Found in: PubMed, PubMed
#
# Title: voting-based intervention planning using ai-generated images
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: what is generative ai?
#    Total occurrences: 2
#    Found in: Springer, Springer
#
# Title: when east meets west: cross-domain drug interaction annotations with large language models and bidirectional neural networks
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: zero-shot learning with minimum instruction to extract social determinants and family history from clinical notes using gpt model
#    Total occurrences: 2
#    Found in: IEEE, PubMed
#
# Title: ﻿evaluation of large language models in pediatric dentistry: a bloom’s taxonomy-based analysis
#    Total occurrences: 2
#    Found in: Elsevier, Elsevier

# %%
# Standardize all dataframes to common schema: id, title, abstract, library, authors, doi, journal, date

# ACM
acm_df["library"] = "acm"
acm_df = acm_df.rename(columns={
    "ID": "id", "title": "title", "abstract": "abstract", "author": "authors",
    "doi": "doi", "journal": "journal", "year": "date"
})
for col in ["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]:
    if col not in acm_df.columns:
        acm_df[col] = pd.NA
acm_df = acm_df[["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]]

# Elsevier
elsevier_df["library"] = "elsevier"
elsevier_df = elsevier_df.rename(columns={
    "ID": "id", "title": "title", "abstract": "abstract", "author": "authors",
    "doi": "doi", "journal": "journal", "year": "date"
})
if "date" in elsevier_df.columns:
    elsevier_df["date"] = elsevier_df["date"].astype(str)
for col in ["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]:
    if col not in elsevier_df.columns:
        elsevier_df[col] = pd.NA
elsevier_df = elsevier_df[["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]]

# IEEE
ieee_df["library"] = "ieee"
ieee_df = ieee_df.rename(columns={
    "ISBNs": "id", "Document Title": "title", "Abstract": "abstract", "Authors": "authors",
    "DOI": "doi", "Publication Title": "journal", "Online Date": "date"
})
for col in ["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]:
    if col not in ieee_df.columns:
        ieee_df[col] = pd.NA
ieee_df = ieee_df[["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]]

# PubMed
pubmed_df["library"] = "pubmed"
pubmed_df = pubmed_df.rename(columns={
    "PMID": "id", "Title": "title", "abstract": "abstract", "Authors": "authors",
    "DOI": "doi", "Journal/Book": "journal", "Create Date": "date"
})
for col in ["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]:
    if col not in pubmed_df.columns:
        pubmed_df[col] = pd.NA
pubmed_df = pubmed_df[["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]]

# Springer - USE ACTUAL COLUMN NAMES from the parquet file
springer_df["library"] = "springer"
springer_df = springer_df.rename(columns={
    "Item Title": "title", "Abstract": "abstract", "Authors": "authors",
    "Item DOI": "doi", "Publication Title": "journal", "Publication Year": "date"
})
# Add ID if missing
if "id" not in springer_df.columns:
    springer_df["id"] = range(len(springer_df))
if "date" in springer_df.columns:
    springer_df["date"] = springer_df["date"].astype(str)
for col in ["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]:
    if col not in springer_df.columns:
        springer_df[col] = pd.NA
springer_df = springer_df[["id", "title", "abstract", "library", "authors", "doi", "journal", "date"]]

# %%
print(f"ACM records after normalization: {len(acm_df)}")
print(f"IEEE records after normalization: {len(ieee_df)}")
print(f"PubMed records after normalization: {len(pubmed_df)}")
print(f"Elsevier records after normalization: {len(elsevier_df)}")
print(f"Springer records after normalization: {len(springer_df)}")
print(f"\nSpringer columns: {springer_df.columns.tolist()}")
print(f"Springer library value counts:\n{springer_df['library'].value_counts()}")
# Out:
# ACM records after normalization: 848
# IEEE records after normalization: 983
# PubMed records after normalization: 3542
# Elsevier records after normalization: 700
# Springer records after normalization: 1000
#
# Springer columns: ['id', 'title', 'abstract', 'library', 'authors', 'doi', 'journal', 'date']
# Springer library value counts:
# library
# springer    1000
# Name: count, dtype: int64

# %%
combined_df = pd.concat([acm_df, elsevier_df, ieee_df, pubmed_df, springer_df], ignore_index=True)
print(len(combined_df))
combined_df
# print group count by date
date_counts = combined_df['date'].value_counts().sort_index()
print("Count of papers by date:")
date_counts
# Out:
# 7073
# Count of papers by date:
# date
# 1 Apr 2024    1
# 1 Dec 2023    1
# 1 Feb 2024    2
# 1 Jan 2024    1
# 1 Jul 2025    1
#              ..
# 9 May 2024    1
# 9 May 2025    1
# 9 Oct 2024    1
# 9 Sep 2024    3
# 9 Sep 2025    1
# Name: count, Length: 1183, dtype: int64

# %%
print("Library counts immediately after concat:")
print(combined_df['library'].value_counts())
print(f"Springer count: {(combined_df['library'] == 'springer').sum()}")
# Out:
# Library counts immediately after concat:
# library
# pubmed      3542
# springer    1000
# ieee         983
# acm          848
# elsevier     700
# Name: count, dtype: int64
# Springer count: 1000

# %%
# Check library counts BEFORE duplicate removal
print("Library counts BEFORE duplicate removal:")
print(combined_df['library'].value_counts())
print(f"\nTotal records: {len(combined_df)}\n")

# create a normalized comparison key
combined_df['title_norm'] = combined_df['title'].str.lower().str.strip()

# group and filter to only duplicated titles
dupes = combined_df[combined_df.duplicated('title_norm', keep=False)]

# now show which libraries the duplicates belong to
result = dupes.groupby('title_norm')['library'].unique().reset_index()

print(result)
# Out:
# Library counts BEFORE duplicate removal:
# library
# pubmed      3542
# springer    1000
# ieee         983
# acm          848
# elsevier     700
# Name: count, dtype: int64
#
# Total records: 7073
#
#                                             title_norm             library
# 0    [impacts and implications of conversational ar...            [pubmed]
# 1    a 360° view for large language models: early d...       [acm, pubmed]
# 2    a case study on using a large language model t...  [pubmed, springer]
# 3    a chatbot based question and answer system for...  [pubmed, springer]
# 4    a collaborative large language model for drug ...  [pubmed, springer]
# ..                                                 ...                 ...
# 524  voting-based intervention planning using ai-ge...      [ieee, pubmed]
# 525                             what is generative ai?          [springer]
# 526  when east meets west: cross-domain drug intera...      [ieee, pubmed]
# 527  zero-shot learning with minimum instruction to...      [ieee, pubmed]
# 528  ﻿evaluation of large language models in pediat...          [elsevier]
#
# [529 rows x 2 columns]

# %%
# DROP DUPLICATES
combined_df['title_norm'] = combined_df['title'].str.lower().str.strip()

# find duplicated keys
dupe_keys = combined_df['title_norm'][combined_df['title_norm'].duplicated(keep=False)]

# remove every row with those keys
combined_df = combined_df[~combined_df['title_norm'].isin(dupe_keys)]

combined_df = combined_df.drop(columns='title_norm')
print(f"Library counts AFTER duplicate removal: {len(combined_df)}")
# remove journal is medRxiv
combined_df = combined_df[combined_df['journal'] != 'medRxiv']
print(f"Library counts AFTER removing medRxiv: {len(combined_df)}")
combined_df
print(f"Amount of papers after duplication removal: {len(combined_df)}")
# Out:
# Library counts AFTER duplicate removal: 5983
# Library counts AFTER removing medRxiv: 5949
# Amount of papers after duplication removal: 5949

# %%
import pandas as pd
import re
 
def clean_doi_logic(doi_val):
    if pd.isna(doi_val):
        return None
    # Convert to string, trim whitespace, and lowercase for consistency
    doi_str = str(doi_val).strip().lower()
    # Remove common URL prefixes and the 'doi:' prefix
    doi_str = re.sub(r'^(https?://(dx\.)?doi\.org/|doi:)', '', doi_str)
    return doi_str
 
# Apply the cleaning function to create the new column
combined_df['doi_cleaned'] = combined_df['doi'].apply(clean_doi_logic)

# %%
import requests
import time
 
def get_crossref_dates_batched(df, batch_size=50):
    success_count = 0
    fail_count = 0
    missing_doi_count = 0
    results = []
    
    total_papers = len(df)
    print(f"Starting batch extraction for {total_papers} papers...")
 
    for i in range(0, total_papers, batch_size):
        batch = df.iloc[i:i+batch_size]
        
        for index, row in batch.iterrows():
            doi = row['doi_cleaned']
            
            if not doi:
                results.append(pd.NaT)
                missing_doi_count += 1
                continue
                
            url = f"https://api.crossref.org/works/{doi}"
            try:
                # 10 second timeout to prevent hanging
                response = requests.get(url, timeout=10)
                if response.status_code == 200:
                    data = response.json()['message']
                    
                    date_info = data.get('published-online') or data.get('issued')
                    
                    if date_info and 'date-parts' in date_info:
                        parts = date_info['date-parts'][0]
                        year = parts[0]
                        month = parts[1] if len(parts) > 1 else 1
                        day = parts[2] if len(parts) > 2 else 1
                        results.append(pd.Timestamp(year=year, month=month, day=day))
                        success_count += 1
                    else:
                        results.append(pd.NaT)
                        fail_count += 1
                else:
                    results.append(pd.NaT)
                    fail_count += 1
            except Exception:
                results.append(pd.NaT)
                fail_count += 1
        
        # Print progress and pause briefly
        print(f"Processed {min(i + batch_size, total_papers)}/{total_papers} papers...")
        time.sleep(1)
 
    # Summary Statistics
    print("\n--- EXTRACTION SUMMARY ---")
    print(f"Successfully Extracted: {success_count}")
    print(f"Failed (API/Data Error): {fail_count}")
    print(f"Missing DOI in Dataframe: {missing_doi_count}")
    print("---------------------------\n")
    
    return results
 
# Execute the batched process
combined_df['date_crossreq'] = get_crossref_dates_batched(combined_df)


combined_df
# Out:
# Starting batch extraction for 5949 papers...
# Processed 50/5949 papers...
# Processed 100/5949 papers...
# Processed 150/5949 papers...
# Processed 200/5949 papers...

# %%
# save to parquet
combined_df['id'] = combined_df['id'].astype(str).str.encode('utf-8')
combined_df.to_parquet("dataset/combined_filtered.parquet", index=False)
